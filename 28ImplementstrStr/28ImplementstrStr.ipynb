# %% [markdown]
# # 28. Implement strStr()

# %% [markdown]
#  * Implement strStr().
#
# Return the index of the first occurrence of needle in haystack, or -1 if needle is not part of haystack.
#
# * Clarification:
#
# What should we return when needle is an empty string? This is a great question to ask during an interview.
#
# * Note: For the purpose of this problem, we will return 0 when needle is an empty string. This is consistent to C's strstr() and Java's indexOf().

# %%
# My own solution
class Solution:
    def strStr(self, haystack: str, needle: str) -> int:
        if(needle == ""):
            return 0
        else:
            str_len = len(haystack)
            pattern_len = len(needle)
        if(pattern_len > str_len):
            return -1
        elif(pattern_len == str_len):
            if(haystack == needle):
                return 0
            else:
                return -1
        else:
            for i in range(str_len - pattern_len + 1):
                # Save potential starting point
                if(haystack[i] == needle[0]):
                    if(haystack[i:i+pattern_len] == needle):
                        return i
                    else:
                        pass
            return -1

# %%
# Alternative super simple solution
class Solution:
    def strStr(self, haystack: str, needle: str) -> int:
        if(needle == ""):
            return 0
        elif (needle in haystack): 
            return haystack.index(needle)
        else:
            return -1

# %% [markdown]
# ## Resume
# 1. My solution beats around 5%
# 2. Alternative: Runtime: 28 ms, faster than 82.94% of Python3 online submissions for Implement strStr().Memory Usage: 14.5 MB, less than 14.35% of Python3 online submissions for Implement strStr().
# 3. Obviously, one need to google first the standadr functions, they are much faster, since probably are written in C++
