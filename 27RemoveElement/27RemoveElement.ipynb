# %% [markdown]
# # 27. Remove Element

# %% [markdown]
# Given an array nums and a value val, remove all instances of that value in-place and return the new length.
#
# Do not allocate extra space for another array, you must do this by modifying the input array in-place with O(1) extra memory.
#
# The order of elements can be changed. It doesn't matter what you leave beyond the new length.
#
# Clarification:
#
# Confused why the returned value is an integer but your answer is an array?
#
# Note that the input array is passed in by reference, which means a modification to the input array will be known to the caller as well.

# %%
class Solution:
    def removeElement(self, nums: List[int], val: int) -> int:
        if(nums == []):
            return 0
        else:
            free_index = 0
            size = len(nums)
            for i in range(len(nums)):
                if(nums[i] != val):
                    nums[free_index] = nums[i]
                    free_index += 1
                else:
                    # reduce size of final array
                    size = size - 1
            return size

# %% [markdown]
# Resume: around 18 min, Runtime: 32 ms, faster than 64.06% of Python3 online submissions for Remove Element.
# Memory Usage: 14.4 MB, less than 9.67% of Python3 online submissions for Remove Element.
